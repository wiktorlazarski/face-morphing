# %%
import os
import cv2

os.chdir("/home/aneta/Desktop/TWM/project/face-morphing")
#os.chdir("../..")

# %%
# !pwd
# Out:
# /home/aneta/Desktop/TWM/project/face-morphing

# %%
import matplotlib.pyplot as plt
from scripts.training import data_loading as dl

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATASET_PATH = os.path.join(os.getcwd(), "data", "dataset", "train")

# %%
dataset = dl.HelenFaceMorphingDataset(dataset_root=DATASET_PATH)

# %%
img, key_points = dataset[48]
img_with_keypoints = img.copy()

for iter in range(1,int((len(key_points)-1)/2)):
    x, y = round(key_points[2*iter-1]), round(key_points[2*iter])
    img_with_keypoints = cv2.circle(img_with_keypoints, (x, y), radius=2, color=(0,255,0), thickness=-1)

f, axis = plt.subplots(1, 2, figsize=(24, 10))
axis[0].imshow(img)
axis[1].imshow(img_with_keypoints)

i = 1
for load_img, load_key_points in dataset:
    if i%250 == 0:
        print(i)
    i += 1
print(i)
# Out:
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 1865
